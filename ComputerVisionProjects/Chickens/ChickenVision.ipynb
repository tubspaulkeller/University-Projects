# %% [markdown]
# # Classification of the breed of chickens using Data Augmentation and Transfer Learning
# In this notebook a CNN is created to distinguish between nine different chickens (of different breeds).
# First a baseline model is built and then enhanced with Data Augmentation and Transfer Learning.

# %% [markdown]
# ## Imports
# All dependencies needed for the model are loaded here.

# %%
# %matplotlib inline
import os
import shutil
import glob
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization, Concatenate, AvgPool2D, Input
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
#import cv2
import numpy as np
#from google.colab.patches import cv2_imshow
from tensorflow.keras import Model
from tensorflow.keras import layers

# %% [markdown]
# ## Load the training and validation images
# The images are in a folder `Chickens` where each of the nine chickens has its own subdirectory.
# For further use the images are copied to `/tmp` where each model will load them from.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# Google Colab
# DATASET_PATH = '/tmp/chickens'
# BASE_PATH = '/content/drive/MyDrive/Chickens'

# Hannes
#BASE_PATH = '/Users/hannes/Google Drive/My Drive/Chickens'
#DATASET_PATH = '/tmp/Chickens'

# Paul
BASE_PATH = '/Users/pkeller/Pictures/chickens'
DATASET_PATH = '/Users/pkeller/Pictures/AIchickens'

blacklisted_files = ['.DS_Store', 'Icon\r']
# Allows to use only a subset of the available classes for training
# breeds = ['Amaretto', 'Aria', 'Chick Pea', 'Espresso', 'Lucifer', 'Oreo', 'Popcorn', 'Pumpkin', 'Whiskey']
breeds = ['Aria', 'Lucifer', 'Popcorn']

# Cleanup existing files to always start with a clean slate
if os.path.exists(DATASET_PATH):
    shutil.rmtree(DATASET_PATH)
    print('Removed existing files')

os.mkdir(DATASET_PATH)

num_copied_files = 0

for breed in breeds:
    breed_source_path = os.path.join(BASE_PATH, breed)
    breed_target_path = os.path.join(DATASET_PATH, breed)

    if os.path.isdir(breed_source_path):
        os.mkdir(breed_target_path)

        for image in os.listdir(breed_source_path):
            sourcePath = os.path.join(breed_source_path, image)
            targetPath = os.path.join(breed_target_path, image)
            shutil.copy(sourcePath, targetPath)
            num_copied_files += 1

# remove .DS_store and other wrong files
for breed in breeds:
    if breed in blacklisted_files:
        path_to_file = os.path.join(DATASET_PATH, breed)
        os.remove(path_to_file)
        print(path_to_file + ' removed')
        num_copied_files -= 1
        continue

    breed_directory = os.path.join(DATASET_PATH, breed)

    if os.path.isdir(breed_directory):
        for filename in os.listdir(breed_directory):
            if filename in blacklisted_files:
                path_to_file = os.path.join(breed_directory, filename)
                os.remove(path_to_file)
                print(path_to_file + ' removed')
                num_copied_files -= 1

print(f"Copied {num_copied_files} files")
print(f"We have {len(breeds)} chickens")
# Out:
# Removed existing files
# Copied 450 files
# We have 3 chickens

# %% [markdown]
# ## Explore dataset
# Next we explore the dataset a bit by showing a random collection of each chicken.

# %%
for breed in breeds:
  breed_directory = os.path.join(DATASET_PATH, breed)
  breed_dir_list = os.listdir(breed_directory)

  print(f"There are {len(breed_dir_list)} images of {breed}.")
  
  # show images of dataset
  rows = 4
  cols = 4
  pic_index = 0
  fig = plt.gcf()
  fig.set_size_inches(cols * 4, rows * 4)
  pic_index+=4
  next_pic = [os.path.join(breed_directory, file_name)
              for file_name in breed_dir_list[pic_index - 4:pic_index]
              ]
  for i, img_path in enumerate(next_pic):
    #subplot
    sp = plt.subplot(rows, cols, i + 1)
    sp.axis('Off') 
    img = mpimg.imread(img_path)
    plt.imshow(img)

  plt.show()
# Out:
# There are 150 images of Aria.
# There are 150 images of Lucifer.
# There are 150 images of Popcorn.

# %% [markdown]
# ## Global parameters
# Here some global parameters are set to be consistent in each model that is built.

# %%
BATCH_SIZE = 32
EPOCHS = 100
SEED = 42
IMG_SIZE = int(244 / 10)
SPLIT = 0.3 # 70% training images and 30% validation images

# %% [markdown]
# #### Tensorboard settings

# %%
import time
# log directory "logs" 
root_logdir = os.path.join(os.curdir, "logs")

# function that prepends the time of a run
def get_run_logdir(name: str = ""):
  run_id = time.strftime("%m_%d-%H_%M")
  run_name = run_id + name
  return os.path.join(root_logdir, run_name)

# %% [markdown]
# ## First Model
# As a start we build a very simple model without any Data Augmentation or Transfer Learning.

# %% [markdown]
# ### Get the training and validation data

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=SPLIT)

train_generator = train_datagen.flow_from_directory(DATASET_PATH,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             target_size=(IMG_SIZE,IMG_SIZE),
                                             subset='training',
                                             seed=SEED)
validation_generator = train_datagen.flow_from_directory(DATASET_PATH,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             target_size=(IMG_SIZE,IMG_SIZE),
                                             subset='validation',
                                             seed=SEED)
# Out:
# Found 315 images belonging to 3 classes.
# Found 135 images belonging to 3 classes.

# %% [markdown]
# ### Create the model

# %%
def create_model():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    input_layer = Conv2D(256, (1, 1), padding='same')(input_tensor)

    blocks = []

    block_1_pool = AvgPool2D((1, 1), padding='same')(input_layer)
    block_1_conv = Conv2D(256, (1, 1), padding='same', activation='relu')(block_1_pool)
    blocks.append(block_1_conv)

    block_2_conv = Conv2D(256, (1, 1), padding='same', activation='relu')(input_layer)
    blocks.append(block_2_conv)

    block_3_conv = Conv2D(384, (1, 1), padding='same', activation='relu')(input_layer)
    block_3_concat_conv_1 = Conv2D(256, (1, 3), padding='same', activation='relu')(block_3_conv)
    block_3_concat_conv_2 = Conv2D(256, (3, 1), padding='same', activation='relu')(block_3_conv)
    block_3_concat = Concatenate(axis=3)([block_3_concat_conv_1, block_3_concat_conv_2])
    blocks.append(block_3_concat)

    block_4_conv_1 = Conv2D(384, (1, 1), padding='same', activation='relu')(input_layer)
    block_4_conv_2 = Conv2D(448, (1, 3), padding='same', activation='relu')(block_4_conv_1)
    block_4_conv_3 = Conv2D(512, (3, 1), padding='same', activation='relu')(block_4_conv_2)
    block_4_concat_conv_1 = Conv2D(256, (1, 3), padding='same', activation='relu')(block_4_conv_3)
    block_4_concat_conv_2 = Conv2D(256, (3, 1), padding='same', activation='relu')(block_4_conv_3)
    block_4_concat = Concatenate(axis=3)([block_4_concat_conv_1, block_4_concat_conv_2])
    blocks.append(block_4_concat)

    full_concat = Concatenate(axis=3)(blocks)
    inception_v4_block = Model(input_tensor, full_concat)

    model = Sequential()
    model.add(inception_v4_block)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(len(breeds), activation='softmax'))

    model.compile(optimizer=RMSprop(learning_rate=1e-4),
                  loss='categorical_crossentropy',
                  metrics = ['accuracy'])

    return model

model = create_model()

model.summary()
# Out:
# 2022-06-28 19:13:44.640553: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-28 19:13:44.640947: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model (Functional)          (None, 24, 24, 1536)      2912448
#
#  flatten (Flatten)           (None, 884736)            0
#
#  dense (Dense)               (None, 256)               226492672
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 229,405,891
# Trainable params: 229,405,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Tensorboard
tensorboard = keras.callbacks.TensorBoard(get_run_logdir("#1.Model"), 
                                             histogram_freq=1,)
          
history = model.fit(train_generator,
                    epochs=int(EPOCHS),
                    validation_data=validation_generator,
                    verbose=1,
                    callbacks=[tensorboard])
# Out:
# Epoch 1/100
# 2022-06-27 08:33:09.353749: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-27 08:33:09.965849: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - ETA: 0s - loss: 4.2582 - accuracy: 0.3841
# 2022-06-27 08:33:24.845414: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 88s 9s/step - loss: 4.2582 - accuracy: 0.3841 - val_loss: 1.3360 - val_accuracy: 0.5926
# Epoch 2/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.8287 - accuracy: 0.6730 - val_loss: 1.2605 - val_accuracy: 0.6296
# Epoch 3/100
# 10/10 [==============================] - 85s 9s/step - loss: 0.7311 - accuracy: 0.7079 - val_loss: 0.3516 - val_accuracy: 0.8963
# Epoch 4/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.2942 - accuracy: 0.8762 - val_loss: 0.3680 - val_accuracy: 0.8667
# Epoch 5/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.3474 - accuracy: 0.8508 - val_loss: 0.3458 - val_accuracy: 0.8889
# Epoch 6/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.1890 - accuracy: 0.9429 - val_loss: 0.1751 - val_accuracy: 0.9704
# Epoch 7/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.2302 - accuracy: 0.9238 - val_loss: 0.2216 - val_accuracy: 0.9259
# Epoch 8/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0551 - accuracy: 0.9905 - val_loss: 0.1339 - val_accuracy: 0.9704
# Epoch 9/100
# 10/10 [==============================] - 85s 9s/step - loss: 0.0341 - accuracy: 0.9937 - val_loss: 0.1428 - val_accuracy: 0.9704
# Epoch 10/100
# 10/10 [==============================] - 85s 9s/step - loss: 0.0459 - accuracy: 0.9841 - val_loss: 1.1820 - val_accuracy: 0.6963
# Epoch 11/100
# 10/10 [==============================] - 85s 9s/step - loss: 0.2059 - accuracy: 0.9333 - val_loss: 0.1264 - val_accuracy: 0.9778
# Epoch 12/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9704
# Epoch 13/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1605 - val_accuracy: 0.9852
# Epoch 14/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2871 - val_accuracy: 0.9037
# Epoch 15/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.1509 - accuracy: 0.9524 - val_loss: 0.1743 - val_accuracy: 0.9704
# Epoch 16/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 0.1336 - val_accuracy: 0.9704
# Epoch 17/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9778
# Epoch 18/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9704
# Epoch 19/100
# 10/10 [==============================] - 87s 9s/step - loss: 7.3145e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9778
# Epoch 20/100
# 10/10 [==============================] - 85s 9s/step - loss: 3.6788e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9778
# Epoch 21/100
# 10/10 [==============================] - 87s 9s/step - loss: 1.6232e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9778
# Epoch 22/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.3643 - accuracy: 0.9460 - val_loss: 0.2195 - val_accuracy: 0.9630
# Epoch 23/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9778
# Epoch 24/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9704
# Epoch 25/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9778
# Epoch 26/100
# 10/10 [==============================] - 87s 9s/step - loss: 9.2072e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9778
# Epoch 27/100
# 10/10 [==============================] - 86s 9s/step - loss: 3.7520e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9778
# Epoch 28/100
# 10/10 [==============================] - 87s 9s/step - loss: 2.5562e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9852
# Epoch 29/100
# 10/10 [==============================] - 87s 9s/step - loss: 2.0957e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9852
# Epoch 30/100
# 10/10 [==============================] - 87s 9s/step - loss: 1.0793e-04 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9778
# Epoch 31/100
# 10/10 [==============================] - 87s 9s/step - loss: 6.5721e-05 - accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 0.9778
# Epoch 32/100
# 10/10 [==============================] - 86s 9s/step - loss: 5.7023e-05 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.9481
# Epoch 33/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.2985 - accuracy: 0.9587 - val_loss: 0.1876 - val_accuracy: 0.9556
# Epoch 34/100
# 10/10 [==============================] - 87s 9s/step - loss: 9.3455e-04 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9630
# Epoch 35/100
# 10/10 [==============================] - 87s 9s/step - loss: 7.2437e-04 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9556
# Epoch 36/100
# 10/10 [==============================] - 87s 9s/step - loss: 3.3875e-04 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9778
# Epoch 37/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.6151e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9852
# Epoch 38/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.4407e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9852
# Epoch 39/100
# 10/10 [==============================] - 85s 9s/step - loss: 6.6653e-05 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9778
# Epoch 40/100
# 10/10 [==============================] - 86s 9s/step - loss: 4.6390e-05 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.9778
# Epoch 41/100
# 10/10 [==============================] - 85s 9s/step - loss: 2.6173e-05 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9852
# Epoch 42/100
# 10/10 [==============================] - 86s 9s/step - loss: 2.5205e-05 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9778
# Epoch 43/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.1816 - accuracy: 0.9460 - val_loss: 0.1589 - val_accuracy: 0.9852
# Epoch 44/100
# 10/10 [==============================] - 87s 9s/step - loss: 7.1138e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9778
# Epoch 45/100
# 10/10 [==============================] - 86s 9s/step - loss: 5.3226e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9852
# Epoch 46/100
# 10/10 [==============================] - 86s 9s/step - loss: 3.7785e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9852
# Epoch 47/100
# 10/10 [==============================] - 86s 9s/step - loss: 2.5853e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9852
# Epoch 48/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.9802e-04 - accuracy: 1.0000 - val_loss: 0.1779 - val_accuracy: 0.9778
# Epoch 49/100
# 10/10 [==============================] - 87s 9s/step - loss: 1.0424e-04 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9778
# Epoch 50/100
# 10/10 [==============================] - 85s 9s/step - loss: 6.0621e-05 - accuracy: 1.0000 - val_loss: 0.1756 - val_accuracy: 0.9852
# Epoch 51/100
#  2/10 [=====>........................] - ETA: 3s - loss: 1.9273e-05 - accuracy: 1.0000
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Caused GPU Hang Error (00000003:kIOGPUCommandBufferCallbackErrorHang)
# 	<AGXG13XFamilyCommandBuffer: 0x41bb60350>
#     label = <none>
#     device = <AGXG13XDevice: 0x16d9e2800>
#         name = Apple M1 Max
#     commandQueue = <AGXG13XFamilyCommandQueue: 0x10f066600>
#         label = <none>
#         device = <AGXG13XDevice: 0x16d9e2800>
#             name = Apple M1 Max
#     retainedReferences = 1
# 10/10 [==============================] - 85s 9s/step - loss: 3.3048e-05 - accuracy: 1.0000 - val_loss: 0.1796 - val_accuracy: 0.9852
# Epoch 52/100
# 10/10 [==============================] - 87s 9s/step - loss: 2.0697e-05 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9852
# Epoch 53/100
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Caused GPU Hang Error (00000003:kIOGPUCommandBufferCallbackErrorHang)
# 	<AGXG13XFamilyCommandBuffer: 0x319022110>
#     label = <none>
#     device = <AGXG13XDevice: 0x16d9e2800>
#         name = Apple M1 Max
#     commandQueue = <AGXG13XFamilyCommandQueue: 0x10f066600>
#         label = <none>
#         device = <AGXG13XDevice: 0x16d9e2800>
#             name = Apple M1 Max
#     retainedReferences = 1
# 10/10 [==============================] - 87s 9s/step - loss: 0.4421 - accuracy: 0.9524 - val_loss: 0.2055 - val_accuracy: 0.9556
# Epoch 54/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.0067 - accuracy: 0.9968 - val_loss: 0.2428 - val_accuracy: 0.9481
# Epoch 55/100
# 10/10 [==============================] - 86s 9s/step - loss: 7.7954e-04 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9630
# Epoch 56/100
# 10/10 [==============================] - 87s 9s/step - loss: 1.4080e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9704
# Epoch 57/100
# 10/10 [==============================] - 87s 9s/step - loss: 4.1158e-05 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9778
# Epoch 58/100
# 10/10 [==============================] - ETA: 0s - loss: 6.2186e-05 - accuracy: 1.0000
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Caused GPU Hang Error (00000003:kIOGPUCommandBufferCallbackErrorHang)
# 	<AGXG13XFamilyCommandBuffer: 0x522df69f0>
#     label = <none>
#     device = <AGXG13XDevice: 0x16d9e2800>
#         name = Apple M1 Max
#     commandQueue = <AGXG13XFamilyCommandQueue: 0x10f066600>
#         label = <none>
#         device = <AGXG13XDevice: 0x16d9e2800>
#             name = Apple M1 Max
#     retainedReferences = 1
# 10/10 [==============================] - 86s 9s/step - loss: 6.2186e-05 - accuracy: 1.0000 - val_loss: 0.4258 - val_accuracy: 0.8444
# Epoch 59/100
# 10/10 [==============================] - 87s 9s/step - loss: 2.9941e-05 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9778
# Epoch 60/100
# 10/10 [==============================] - 86s 9s/step - loss: 2.5684e-05 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9852
# Epoch 61/100
# 10/10 [==============================] - 87s 9s/step - loss: 1.7073e-05 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9852
# Epoch 62/100
# 10/10 [==============================] - 86s 9s/step - loss: 6.2849e-05 - accuracy: 1.0000 - val_loss: 0.3154 - val_accuracy: 0.9185
# Epoch 63/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.2991 - val_accuracy: 0.9407
# Epoch 64/100
# 10/10 [==============================] - 86s 9s/step - loss: 5.7884e-05 - accuracy: 1.0000 - val_loss: 0.2794 - val_accuracy: 0.9556
# Epoch 65/100
# 10/10 [==============================] - 87s 9s/step - loss: 3.3316e-05 - accuracy: 1.0000 - val_loss: 0.2551 - val_accuracy: 0.9556
# Epoch 66/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.6277e-05 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9556
# Epoch 67/100
# 10/10 [==============================] - 87s 9s/step - loss: 1.8997e-05 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9630
# Epoch 68/100
# 10/10 [==============================] - 85s 9s/step - loss: 9.0224e-06 - accuracy: 1.0000 - val_loss: 0.2377 - val_accuracy: 0.9704
# Epoch 69/100
# 10/10 [==============================] - 86s 9s/step - loss: 5.8945e-06 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9704
# Epoch 70/100
# 10/10 [==============================] - 86s 9s/step - loss: 4.7340e-06 - accuracy: 1.0000 - val_loss: 0.2408 - val_accuracy: 0.9630
# Epoch 71/100
# 10/10 [==============================] - 86s 9s/step - loss: 3.1966e-06 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9778
# Epoch 72/100
# 10/10 [==============================] - 85s 9s/step - loss: 3.5313e-06 - accuracy: 1.0000 - val_loss: 0.2330 - val_accuracy: 0.9778
# Epoch 73/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.6534e-06 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9704
# Epoch 74/100
# 10/10 [==============================] - 86s 9s/step - loss: 8.1738e-07 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9704
# Epoch 75/100
# 10/10 [==============================] - 86s 9s/step - loss: 8.1370e-07 - accuracy: 1.0000 - val_loss: 0.2412 - val_accuracy: 0.9704
# Epoch 76/100
# 10/10 [==============================] - 86s 9s/step - loss: 7.2766e-07 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9704
# Epoch 77/100
# 10/10 [==============================] - ETA: 0s - loss: 2.8042e-07 - accuracy: 1.0000
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Caused GPU Hang Error (00000003:kIOGPUCommandBufferCallbackErrorHang)
# 	<AGXG13XFamilyCommandBuffer: 0x41bb743b0>
#     label = <none>
#     device = <AGXG13XDevice: 0x16d9e2800>
#         name = Apple M1 Max
#     commandQueue = <AGXG13XFamilyCommandQueue: 0x10f066600>
#         label = <none>
#         device = <AGXG13XDevice: 0x16d9e2800>
#             name = Apple M1 Max
#     retainedReferences = 1
# 10/10 [==============================] - 87s 9s/step - loss: 2.8042e-07 - accuracy: 1.0000 - val_loss: 0.4862 - val_accuracy: 0.8074
# Epoch 78/100
# 10/10 [==============================] - 87s 9s/step - loss: 4.5591e-07 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9704
# Epoch 79/100
# 10/10 [==============================] - 86s 9s/step - loss: 3.9374e-07 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9778
# Epoch 80/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.8572e-07 - accuracy: 1.0000 - val_loss: 0.2624 - val_accuracy: 0.9778
# Epoch 81/100
# 10/10 [==============================] - 86s 9s/step - loss: 7.8957e-08 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9778
# Epoch 82/100
# 10/10 [==============================] - 87s 9s/step - loss: 2.8697e-07 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9778
# Epoch 83/100
# 10/10 [==============================] - 86s 9s/step - loss: 2.4946e-07 - accuracy: 1.0000 - val_loss: 0.2755 - val_accuracy: 0.9630
# Epoch 84/100
#  5/10 [==============>...............] - ETA: 5s - loss: 2.3989e-07 - accuracy: 1.0000
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Caused GPU Hang Error (00000003:kIOGPUCommandBufferCallbackErrorHang)
# 	<AGXG13XFamilyCommandBuffer: 0x41b8982f0>
#     label = <none>
#     device = <AGXG13XDevice: 0x16d9e2800>
#         name = Apple M1 Max
#     commandQueue = <AGXG13XFamilyCommandQueue: 0x10f066600>
#         label = <none>
#         device = <AGXG13XDevice: 0x16d9e2800>
#             name = Apple M1 Max
#     retainedReferences = 1
# 10/10 [==============================] - 85s 9s/step - loss: 1.7051e-07 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9852
# Epoch 85/100
# 10/10 [==============================] - 87s 9s/step - loss: 5.2988e-08 - accuracy: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9778
# Epoch 86/100
# 10/10 [==============================] - 87s 9s/step - loss: 5.1414e-08 - accuracy: 1.0000 - val_loss: 0.2734 - val_accuracy: 0.9852
# Epoch 87/100
# 10/10 [==============================] - 86s 9s/step - loss: 4.7742e-08 - accuracy: 1.0000 - val_loss: 0.2734 - val_accuracy: 0.9852
# Epoch 88/100
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Caused GPU Hang Error (00000003:kIOGPUCommandBufferCallbackErrorHang)
# 	<AGXG13XFamilyCommandBuffer: 0x3d4da1ec0>
#     label = <none>
#     device = <AGXG13XDevice: 0x16d9e2800>
#         name = Apple M1 Max
#     commandQueue = <AGXG13XFamilyCommandQueue: 0x10f066600>
#         label = <none>
#         device = <AGXG13XDevice: 0x16d9e2800>
#             name = Apple M1 Max
#     retainedReferences = 1
# 10/10 [==============================] - 86s 9s/step - loss: 0.2052 - accuracy: 0.9651 - val_loss: 0.2009 - val_accuracy: 0.9778
# Epoch 89/100
# 10/10 [==============================] - 86s 9s/step - loss: 5.3008e-05 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9778
# Epoch 90/100
# 10/10 [==============================] - 86s 9s/step - loss: 4.0077e-05 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9778
# Epoch 91/100
# 10/10 [==============================] - 85s 9s/step - loss: 2.3448e-05 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9778
# Epoch 92/100
# 10/10 [==============================] - 85s 9s/step - loss: 1.3913e-05 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9778
# Epoch 93/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.2987e-05 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.9778
# Epoch 94/100
# 10/10 [==============================] - 86s 9s/step - loss: 1.7496e-05 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9778
# Epoch 95/100
# 10/10 [==============================] - 87s 9s/step - loss: 6.9873e-06 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9778
# Epoch 96/100
# 10/10 [==============================] - 87s 9s/step - loss: 8.5880e-06 - accuracy: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9778
# Epoch 97/100
# 10/10 [==============================] - 87s 9s/step - loss: 5.6944e-06 - accuracy: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.9778
# Epoch 98/100
# 10/10 [==============================] - 86s 9s/step - loss: 6.7163e-06 - accuracy: 1.0000 - val_loss: 0.2471 - val_accuracy: 0.9778
# Epoch 99/100
# 10/10 [==============================] - 84s 9s/step - loss: 3.0229e-06 - accuracy: 1.0000 - val_loss: 0.2471 - val_accuracy: 0.9778
# Epoch 100/100
# 10/10 [==============================] - 87s 9s/step - loss: 1.7134e-06 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 0.9778

# %%
def plot_training_validation_accuracy_loss(history_to_plot):
    acc = history_to_plot.history['accuracy']
    val_acc = history_to_plot.history['val_accuracy']
    loss = history_to_plot.history['loss']
    val_loss = history_to_plot.history['val_loss']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'r', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %%
plot_training_validation_accuracy_loss(history)

# %% [markdown]
# As we can see the accuracy is not even near a good value.
# In the next parts we will try some measures to gain a better accuracy.

# %% [markdown]
# ## 1. Measure: Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=SPLIT,
                                            rotation_range=20,
                                            width_shift_range=0.1,                               
                                            height_shift_range=0.1,
                                            shear_range=0.1,                          
                                            zoom_range=0.1,                          
                                            horizontal_flip=True,
                                            fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(DATASET_PATH,
                                            shuffle=True,
                                            batch_size=BATCH_SIZE,
                                            target_size=(IMG_SIZE,IMG_SIZE),
                                            subset='training',
                                            seed=SEED)

test_datagen = ImageDataGenerator(rescale=1./255, validation_split=SPLIT)

validation_generator = test_datagen.flow_from_directory(DATASET_PATH,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             target_size=(IMG_SIZE,IMG_SIZE),
                                             subset='validation',
                                             seed=SEED)
# Out:
# Found 315 images belonging to 3 classes.
# Found 135 images belonging to 3 classes.

# %%
model = create_model()

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_1 (Functional)        (None, 24, 24, 1536)      2912448
#
#  flatten_1 (Flatten)         (None, 884736)            0
#
#  dense_2 (Dense)             (None, 256)               226492672
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 229,405,891
# Trainable params: 229,405,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Tensorboard
tensorboard = keras.callbacks.TensorBoard(get_run_logdir("#2.Model"), 
                                             histogram_freq=1,)
         
history = model.fit(
            train_generator,
            epochs=EPOCHS,
            validation_data=validation_generator,
            verbose=1,
            callbacks=[tensorboard])
# Out:
# Epoch 1/35
# 10/10 [==============================] - ETA: 0s - loss: 1.8872 - accuracy: 0.4222
# 2022-06-28 19:15:19.277379: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 92s 10s/step - loss: 1.8872 - accuracy: 0.4222 - val_loss: 0.8857 - val_accuracy: 0.4222
# Epoch 2/35
# 10/10 [==============================] - 86s 9s/step - loss: 0.8759 - accuracy: 0.6317 - val_loss: 0.8892 - val_accuracy: 0.6074
# Epoch 3/35
# 10/10 [==============================] - 88s 9s/step - loss: 0.6408 - accuracy: 0.7302 - val_loss: 0.9820 - val_accuracy: 0.5926
# Epoch 4/35
# 10/10 [==============================] - 88s 9s/step - loss: 0.6103 - accuracy: 0.7651 - val_loss: 0.7326 - val_accuracy: 0.6963
# Epoch 5/35
# 10/10 [==============================] - 89s 10s/step - loss: 0.4417 - accuracy: 0.8286 - val_loss: 0.1988 - val_accuracy: 0.9556
# Epoch 6/35
#  3/10 [========>.....................] - ETA: 6s - loss: 0.3139 - accuracy: 0.8681
# Error: command buffer exited with error status.
# 	The Metal Performance Shaders operations encoded on it may not have completed.
# 	Error:
# 	(null)
# 	Caused GPU Hang Error (00000003:kIOGPUCommandBufferCallbackErrorHang)
# 	<AGXG13XFamilyCommandBuffer: 0x306a16350>
#     label = <none>
#     device = <AGXG13XDevice: 0x10d72fc00>
#         name = Apple M1 Max
#     commandQueue = <AGXG13XFamilyCommandQueue: 0x11cbfc600>
#         label = <none>
#         device = <AGXG13XDevice: 0x10d72fc00>
#             name = Apple M1 Max
#     retainedReferences = 1
# 10/10 [==============================] - 89s 10s/step - loss: 0.5701 - accuracy: 0.8190 - val_loss: 0.3319 - val_accuracy: 0.8889
# Epoch 7/35
# 10/10 [==============================] - 88s 10s/step - loss: 0.3305 - accuracy: 0.8794 - val_loss: 0.4115 - val_accuracy: 0.8370
# Epoch 8/35
# 10/10 [==============================] - 90s 10s/step - loss: 0.2567 - accuracy: 0.9143 - val_loss: 0.6600 - val_accuracy: 0.7926
# Epoch 9/35
# 10/10 [==============================] - 88s 9s/step - loss: 0
- val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 34/35
# 10/10 [==============================] - 88s 9s/step - loss: 0.0714 - accuracy: 0.9683 - val_loss: 0.0504 - val_accuracy: 0.9778
# Epoch 35/35
# 10/10 [==============================] - 88s 10s/step - loss: 0.1267 - accuracy: 0.9619 - val_loss: 0.1473 - val_accuracy: 0.9556

# %%
plot_training_validation_accuracy_loss(history)

# %% [markdown]
# **2. Measure: VGG19Model**

# %%
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=SPLIT,
                                   rotation_range=20,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(DATASET_PATH,
                                                    shuffle=True,
                                                    batch_size=BATCH_SIZE,
                                                    target_size=(244,244),
                                                    subset='training',
                                                    seed=SEED)

test_datagen = ImageDataGenerator(rescale=1./255, validation_split=SPLIT)

validation_generator = test_datagen.flow_from_directory(DATASET_PATH,
                                                        shuffle=True,
                                                        batch_size=BATCH_SIZE,
                                                        target_size=(244,244),
                                                        subset='validation',
                                                        seed=SEED)
# Out:
# Found 315 images belonging to 3 classes.
# Found 135 images belonging to 3 classes.

# %%
# Import the VGG-19 model  
from keras.applications.vgg19 import VGG19

vgg19_model = VGG19(input_shape = (244, 244, 3),
include_top = False, 
weights = 'imagenet')

# %%
for layer in vgg19_model.layers:
    layer.trainable = False

# %%
vgg19_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 244, 244, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 244, 244, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 244, 244, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 122, 122, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 122, 122, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 122, 122, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 61, 61, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 61, 61, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 61, 61, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 61, 61, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 61, 61, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 30, 30, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 30, 30, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# #### Hyperparamater

# %%
from tensorboard.plugins.hparams import api as hp
metric_accuracy = 'accuracy'
num_of_units = hp.HParam('num_units', hp.Discrete([32, 64, 256, 1024]))
#num_of_units_two = hp.HParam('num_units_two', hp.Discrete([32, 64, 256, 1024]))
#num_of_units_three = hp.HParam('num_units_three', hp.Discrete([32, 64, 256, 1024]))
dropout = hp.HParam('dropout', hp.RealInterval(0.2, 0.4))
#opti = hp.HParam('optimizer', hp.Discrete(['adam', 'rmsprop']))

# %%
from keras import layers
from keras import Model

def create_and_train_model(hparams: dict, vgg19_model):
    last_layer = layers.Flatten()(vgg19_model.get_layer('block5_conv4').output)

    last_layer = layers.Dense(hparams[num_of_units], activation='relu')(last_layer)
    last_layer = layers.Dropout(hparams[dropout])(last_layer) 

    last_layer = layers.Dense(hparams[num_of_units], activation='relu')(last_layer)
    last_layer = layers.Dropout(hparams[dropout])(last_layer) 

    last_layer = layers.Dense(hparams[num_of_units], activation='relu')(last_layer)
    last_layer = layers.Dropout(hparams[dropout])(last_layer)     
     
    last_layer = layers.Dense(len(breeds), activation='softmax')(last_layer)
    
    model = Model(inputs=vgg19_model.input, outputs=last_layer)

    model.compile(optimizer = 'rmsprop',
                  loss = 'categorical_crossentropy', 
                  metrics = ['accuracy'])
    
    model.fit(train_generator, validation_data=(validation_generator), epochs=50)
    
    loss, accuracy = model.evaluate(validation_generator)
    
    return accuracy

# %%
# Set up for Tensorboardhyperparamtest
if os.path.exists('logs/param_test'):
  shutil.rmtree('logs/param_test')

with tf.summary.create_file_writer('logs/param_test').as_default():
    hp.hparams_config(
        #hparams=[num_of_units,num_of_units_two,num_of_units_three, dropout],
        hparams=[num_of_units, dropout],
        metrics=[hp.Metric(metric_accuracy, display_name='Accuracy')],)

def experiment(experiment_dir, hparams):
    with tf.summary.create_file_writer(experiment_dir).as_default():
        hp.hparams(hparams)
        accuracy = create_and_train_model(hparams, vgg19_model) # experiment run
        tf.summary.scalar(metric_accuracy, accuracy, step=1)

# %%
test_number = 0 # test counter
for num_units in num_of_units.domain.values: # try all four different values
    #for num_units_two in num_of_units_two.domain.values: # try all four different values
     #   for num_units_three in num_of_units_three.domain.values: # try all four different values
    for dropout_rate in (dropout.domain.min_value, dropout.domain.max_value): # try min and max value of dropout
        #for optimizer in opti.domain.values: # try all two different optimizers
        hparams = {
                num_of_units: num_units,
                  #  num_of_units_two: num_units_two,
                   # num_of_units_three: num_units_three,
                dropout: dropout_rate,
              #  opti: optimizer,
        }

        test_name = f'Test {test_number}'
        print(f'Starting Test: {test_name}')
        print({h.name: hparams[h] for h in hparams})
        experiment('logs/param_test/' + test_name, hparams)
        test_number += 1
# Out:
# Starting Test: Test 0
# {'num_units': 32, 'dropout': 0.2, 'optimizer': 'rmsprop'}
# Epoch 1/50
# 2022-06-27 15:09:08.767053: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - ETA: 0s - loss: 5.0487 - accuracy: 0.3460
# 2022-06-27 15:09:25.276563: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 22s 2s/step - loss: 5.0487 - accuracy: 0.3460 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 2/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0991 - accuracy: 0.3270 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 3/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 4/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.1087 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 5/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0991 - accuracy: 0.3302 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 6/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0992 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 7/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 8/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.5964 - accuracy: 0.3143 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 9/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 10/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 11/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0991 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 12/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 13/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0989 - accuracy: 0.3365 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 14/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0988 - accuracy: 0.3206 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 15/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0990 - accuracy: 0.3365 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 16/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0988 - accuracy: 0.3111 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 17/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0988 - accuracy: 0.3238 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 18/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0987 - accuracy: 0.3460 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 19/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0989 - accuracy: 0.2952 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 20/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0986 - accuracy: 0.3460 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 21/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0986 - accuracy: 0.3460 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 22/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0990 - accuracy: 0.3460 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 23/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0990 - accuracy: 0.3111 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 24/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0987 - accuracy: 0.3302 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 25/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0990 - accuracy: 0.3048 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 26/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0983 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 27/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0984 - accuracy: 0.3524 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 28/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3206 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 29/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0991 - accuracy: 0.3079 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 30/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3365 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 31/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0990 - accuracy: 0.3238 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 32/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3238 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 33/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0986 - accuracy: 0.3492 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 34/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3206 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 35/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0986 - accuracy: 0.2984 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 36/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3397 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 37/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3238 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 38/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0990 - accuracy: 0.2889 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 39/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0991 - accuracy: 0.3111 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 40/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0991 - accuracy: 0.2921 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 41/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0988 - accuracy: 0.3175 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 42/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0990 - accuracy: 0.3079 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 43/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0985 - accuracy: 0.3365 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 44/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3238 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 45/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0985 - accuracy: 0.3397 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 46/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0983 - accuracy: 0.3365 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 47/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3175 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 48/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.2889 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 49/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0985 - accuracy: 0.3429 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 50/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3111 - val_loss: 1.0986 - val_accuracy: 0.3333
# 5/5 [==============================] - 5s 853ms/step - loss: 1.0986 - accuracy: 0.3333
# Starting Test: Test 1
# {'num_units': 32, 'dropout': 0.4, 'optimizer': 'rmsprop'}
# Epoch 1/50
# 2022-06-27 15:25:35.071348: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - ETA: 0s - loss: 4.0836 - accuracy: 0.4063
# 2022-06-27 15:25:50.934065: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 21s 2s/step - loss: 4.0836 - accuracy: 0.4063 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 2/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.8917 - accuracy: 0.3270 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 3/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.2304 - accuracy: 0.3397 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 4/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 5/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 6/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 7/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.3414 - accuracy: 0.3460 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 8/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 9/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0990 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 10/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 11/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 12/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 13/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0991 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 14/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 15/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 16/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 17/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 18/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 19/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 20/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 21/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 22/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 23/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 24/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 25/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 26/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0991 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 27/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 28/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 29/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 30/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0991 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 31/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 32/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0989 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 33/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0986 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 34/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 35/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 36/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 37/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 38/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 39/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 40/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 41/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 42/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 43/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 44/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 45/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3175 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 46/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3143 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 47/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3175 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 48/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0988 - accuracy: 0.3429 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 49/50
# 10/10 [==============================] - 19s 2s/step - loss: 1.0987 - accuracy: 0.3048 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 50/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0986 - accuracy: 0.3302 - val_loss: 1.0986 - val_accuracy: 0.3333
# 5/5 [==============================] - 5s 844ms/step - loss: 1.0986 - accuracy: 0.3333
# Starting Test: Test 2
# {'num_units': 64, 'dropout': 0.2, 'optimizer': 'rmsprop'}
# Epoch 1/50
# 2022-06-27 15:41:55.391986: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - ETA: 0s - loss: 6.2329 - accuracy: 0.3429
# 2022-06-27 15:42:11.214270: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 21s 2s/step - loss: 6.2329 - accuracy: 0.3429 - val_loss: 2.1263 - val_accuracy: 0.3333
# Epoch 2/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.6106 - accuracy: 0.3651 - val_loss: 1.0438 - val_accuracy: 0.6370
# Epoch 3/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0917 - accuracy: 0.3619 - val_loss: 1.2029 - val_accuracy: 0.3333
# Epoch 4/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1152 - accuracy: 0.3619 - val_loss: 1.0275 - val_accuracy: 0.4593
# Epoch 5/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1085 - accuracy: 0.3492 - val_loss: 1.0671 - val_accuracy: 0.5259
# Epoch 6/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.
# Epoch 32/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1413 - accuracy: 0.3111 - val_loss: 1.0384 - val_accuracy: 0.3333
# Epoch 33/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0949 - accuracy: 0.3302 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 34/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1166 - accuracy: 0.3556 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 35/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1700 - accuracy: 0.3619 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 36/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.3557 - accuracy: 0.3111 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 37/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0996 - accuracy: 0.3397 - val_loss: 1.0991 - val_accuracy: 0.3333
# Epoch 38/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0939 - accuracy: 0.3111 - val_loss: 1.1447 - val_accuracy: 0.3111
# Epoch 39/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1477 - accuracy: 0.3206 - val_loss: 1.1252 - val_accuracy: 0.2815
# Epoch 40/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0864 - accuracy: 0.3397 - val_loss: 1.1831 - val_accuracy: 0.3333
# Epoch 41/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1550 - accuracy: 0.3302 - val_loss: 1.1127 - val_accuracy: 0.3111
# Epoch 42/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1450 - accuracy: 0.3238 - val_loss: 1.7485 - val_accuracy: 0.3333
# Epoch 43/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.2355 - accuracy: 0.3016 - val_loss: 1.0993 - val_accuracy: 0.3333
# Epoch 44/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0914 - accuracy: 0.3429 - val_loss: 1.1010 - val_accuracy: 0.3111
# Epoch 45/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0891 - accuracy: 0.3619 - val_loss: 1.1056 - val_accuracy: 0.3630
# Epoch 46/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1764 - accuracy: 0.3937 - val_loss: 1.1064 - val_accuracy: 0.2963
# Epoch 47/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0897 - accuracy: 0.3175 - val_loss: 1.1304 - val_accuracy: 0.2963
# Epoch 48/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.0885 - accuracy: 0.3492 - val_loss: 1.1313 - val_accuracy: 0.3259
# Epoch 49/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.1391 - accuracy: 0.3302 - val_loss: 1.1329 - val_accuracy: 0.3111
# Epoch 50/50
# 10/10 [==============================] - 20s 2s/step - loss: 1.2918 - accuracy: 0.3365 - val_loss: 1.0550 - val_accuracy: 0.4889
# 5/5 [==============================] - 5s 798ms/step - loss: 1.0550 - accuracy: 0.4889

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/param_test
# %reload_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 3762), started 3:07:21 ago. (Use '!kill 3762' to kill it.)
#       <iframe id="tensorboard-frame-77182bec5f3014c4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-77182bec5f3014c4");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# #### Result of hyperparamtest
#
# number of units: 1024
# dropout: 0.2
# optimizer: rmsprop

# %% [markdown]
# #### Create final model

# %%
def create_final_model(vgg19_model):
    last_layer = layers.Flatten()(vgg19_model.get_layer('block5_conv4').output)
    last_layer = layers.Dense(1024, activation='relu')(last_layer)
    last_layer = layers.Dropout(0.2)(last_layer)
    last_layer = layers.Dense(1024, activation='relu')(last_layer)
    last_layer = layers.Dropout(0.2)(last_layer)
    last_layer = layers.Dense(1024, activation='relu')(last_layer)
    last_layer = layers.Dropout(0.2)(last_layer)
    last_layer = layers.Dense(len(breeds), activation='softmax')(last_layer)

    model = Model(inputs=vgg19_model.input, outputs=last_layer)

    model.compile(optimizer = 'rmsprop', 
                  loss = 'categorical_crossentropy', 
                  metrics = ['accuracy'])
    return model

# %%
model = create_final_model(vgg19_model)

# %%
# Tensorboard
tensorboard = keras.callbacks.TensorBoard(get_run_logdir("#3.Model"), 
                                             histogram_freq=1,)
history = model.fit(
            train_generator,
            epochs=EPOCHS,
            validation_data=validation_generator,
            verbose=1, 
            callbacks=[tensorboard])
# Out:
# Epoch 1/100
# 2022-06-27 17:52:52.105187: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - ETA: 0s - loss: 64.0682 - accuracy: 0.3365
# 2022-06-27 17:53:08.898515: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#
100
# 10/10 [==============================] - 58s 6s/step - loss: 0.0319 - accuracy: 0.9873 - val_loss: 0.8803 - val_accuracy: 0.8444
# Epoch 59/100
# 10/10 [==============================] - 58s 6s/step - loss: 0.5594 - accuracy: 0.8762 - val_loss: 0.9073 - val_accuracy: 0.7481
# Epoch 60/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.0338 - accuracy: 0.9873 - val_loss: 1.3271 - val_accuracy: 0.8074
# Epoch 61/100
# 10/10 [==============================] - 57s 6s/step - loss: 0.3067 - accuracy: 0.9365 - val_loss: 0.7080 - val_accuracy: 0.7778
# Epoch 62/100
# 10/10 [==============================] - 59s 6s/step - loss: 0.0209 - accuracy: 0.9968 - val_loss: 0.8657 - val_accuracy: 0.8148
# Epoch 63/100
# 10/10 [==============================] - 58s 6s/step - loss: 0.0902 - accuracy: 0.9810 - val_loss: 1.1173 - val_accuracy: 0.7185
# Epoch 64/100
# 10/10 [==============================] - 57s 6s/step - loss: 0.0554 - accuracy: 0.9714 - val_loss: 0.8121 - val_accuracy: 0.8222
# Epoch 65/100
# 10/10 [==============================] - 59s 6s/step - loss: 0.5385 - accuracy: 0.8952 - val_loss: 0.6123 - val_accuracy: 0.8444
# Epoch 66/100
# 10/10 [==============================] - 58s 6s/step - loss: 0.0305 - accuracy: 0.9937 - val_loss: 0.9237 - val_accuracy: 0.7556
# Epoch 67/100
# 10/10 [==============================] - 59s 6s/step - loss: 0.0492 - accuracy: 0.9841 - val_loss: 0.9576 - val_accuracy: 0.8222
# Epoch 68/100
# 10/10 [==============================] - 59s 6s/step - loss: 0.3026 - accuracy: 0.9270 - val_loss: 0.6805 - val_accuracy: 0.8000
# Epoch 69/100
# 10/10 [==============================] - 59s 6s/step - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.7867 - val_accuracy: 0.8519
# Epoch 70/100
# 10/10 [==============================] - 58s 6s/step - loss: 0.0214 - accuracy: 0.9968 - val_loss: 1.9225 - val_accuracy: 0.7852
# Epoch 71/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.2311 - accuracy: 0.9333 - val_loss: 0.7527 - val_accuracy: 0.8148
# Epoch 72/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.8144 - val_accuracy: 0.8519
# Epoch 73/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.2266 - accuracy: 0.9587 - val_loss: 0.9401 - val_accuracy: 0.8222
# Epoch 74/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0962 - accuracy: 0.9778 - val_loss: 0.8228 - val_accuracy: 0.8074
# Epoch 75/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0299 - accuracy: 0.9841 - val_loss: 1.4991 - val_accuracy: 0.7778
# Epoch 76/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.4628 - accuracy: 0.8889 - val_loss: 0.8031 - val_accuracy: 0.8074
# Epoch 77/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0188 - accuracy: 0.9968 - val_loss: 0.9518 - val_accuracy: 0.8222
# Epoch 78/100
# 10/10 [==============================] - 53s 6s/step - loss: 0.0682 - accuracy: 0.9746 - val_loss: 1.1603 - val_accuracy: 0.8222
# Epoch 79/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0299 - accuracy: 0.9968 - val_loss: 1.3787 - val_accuracy: 0.7556
# Epoch 80/100
# 10/10 [==============================] - 53s 6s/step - loss: 0.3351 - accuracy: 0.9238 - val_loss: 1.0515 - val_accuracy: 0.8074
# Epoch 81/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0064 - accuracy: 0.9968 - val_loss: 1.3655 - val_accuracy: 0.8222
# Epoch 82/100
# 10/10 [==============================] - 54s 6s/step - loss: 0.0928 - accuracy: 0.9746 - val_loss: 1.7306 - val_accuracy: 0.7185
# Epoch 83/100
# 10/10 [==============================] - 53s 6s/step - loss: 0.0356 - accuracy: 0.9841 - val_loss: 1.5867 - val_accuracy: 0.7481
# Epoch 84/100
# 10/10 [==============================] - 54s 6s/step - loss: 0.2015 - accuracy: 0.9524 - val_loss: 1.3487 - val_accuracy: 0.7481
# Epoch 85/100
# 10/10 [==============================] - 54s 6s/step - loss: 0.0386 - accuracy: 0.9810 - val_loss: 1.2831 - val_accuracy: 0.7852
# Epoch 86/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.5094 - val_accuracy: 0.8074
# Epoch 87/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.4388 - accuracy: 0.9460 - val_loss: 1.5042 - val_accuracy: 0.8074
# Epoch 88/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 1.6152 - val_accuracy: 0.7556
# Epoch 89/100
# 10/10 [==============================] - 54s 6s/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 3.3356 - val_accuracy: 0.7778
# Epoch 90/100
# 10/10 [==============================] - 54s 6s/step - loss: 0.9358 - accuracy: 0.9111 - val_loss: 1.4781 - val_accuracy: 0.7037
# Epoch 91/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.0486 - accuracy: 0.9873 - val_loss: 1.0252 - val_accuracy: 0.7852
# Epoch 92/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.0274 - accuracy: 0.9873 - val_loss: 1.1974 - val_accuracy: 0.7926
# Epoch 93/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.3130 - accuracy: 0.9270 - val_loss: 1.0324 - val_accuracy: 0.7481
# Epoch 94/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 1.2889 - val_accuracy: 0.7556
# Epoch 95/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0067 - accuracy: 0.9968 - val_loss: 1.4212 - val_accuracy: 0.7852
# Epoch 96/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0167 - accuracy: 0.9905 - val_loss: 1.7957 - val_accuracy: 0.8370
# Epoch 97/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.7416 - accuracy: 0.9016 - val_loss: 1.2785 - val_accuracy: 0.6741
# Epoch 98/100
# 10/10 [==============================] - 56s 6s/step - loss: 0.0420 - accuracy: 0.9937 - val_loss: 2.2229 - val_accuracy: 0.8000
# Epoch 99/100
# 10/10 [==============================] - 55s 6s/step - loss: 0.0155 - accuracy: 0.9937 - val_loss: 1.7327 - val_accuracy: 0.7926
# Epoch 100/100
# 10/10 [==============================] - 54s 6s/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 3.1635 - val_accuracy: 0.7778

# %%
plot_training_validation_accuracy_loss(history)

# %% [markdown]
# ### Tensorboard

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./logs
# %reload_ext tensorboard
# Out:
#       <iframe id="tensorboard-frame-d95a6265589731f9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d95a6265589731f9");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Prediction with second model (Data Augmentation)

# %%
#Prediction
import matplotlib.image as mpimg
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt

def model_makes_prediction(model):
    guesses_path = '/Users/pkeller/Pictures/ChickenGuesses/'
    guesses_images = os.listdir(guesses_path)
    counter = 1
    for filename in guesses_images:
        # predicting images
        if(filename != '.DS_Store'):
            path = guesses_path + filename
            img = keras.utils.load_img(path, target_size=(IMG_SIZE,IMG_SIZE))
            x = keras.utils.img_to_array(img)
            x /= 255
            x = np.expand_dims(x, axis=0)
            images = np.vstack([x])
            # get classes
            classes = model.predict(images, batch_size=10)
            # define classmembers
            aria = classes[0][0]
            lucifer = classes[0][1]
            popcorn = classes[0][2]
            # get maxVal of the array
            max_value = np.amax(classes)
            # evaluate guess
            if(max_value == aria):
                prediction = "Aria"
            elif(max_value == lucifer):
                prediction = "Lucifer"
            elif(max_value == popcorn):
                prediction = "Popcorn"
            # show img with guess of the CNN
            img2 = mpimg.imread(path)
            plt.imshow(img2)
            plt.axis('off')
            plt.title(str(counter) + ". PREDICTED AS : " + prediction + "\n REALITY: " + filename)
            counter = counter + 1
            
            plt.show()

# %%
# call prediction method
model_makes_prediction(model)
# Out:
# 2022-06-28 20:07:22.450560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
